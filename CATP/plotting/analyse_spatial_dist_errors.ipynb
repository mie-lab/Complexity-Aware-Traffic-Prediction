# %%
import numpy as np
import os
import sys
import glob
from smartprint import smartprint as sprint

sys.path.append('../')

import config
import matplotlib.pyplot as plt
import scipy.stats

fileprefix_list = ["madrid-4-1-55-"]

cx_count = 3000 # number of points used to compute Cx
batch_size_m_predict = 55 

for prefix in fileprefix_list:
    filenames = glob.glob(os.path.join(os.getcwd(), 
                                       "Spatial_results_validation_errors/", prefix + "-spatial-errors", "*.npy"))
    a = 0
    for npy in filenames:
        a = a + np.load(npy)
    a = a/len(filenames)
    sprint (len(filenames))

    
    mean_plot_across_io_length = np.mean(a, axis=0)
    
    max_ = np.max(a)
    sprint (mean_plot_across_io_length.shape)
    sprint (np.mean(mean_plot_across_io_length)/batch_size_m_predict)
    
    plt.imshow((mean_plot_across_io_length[:, :, 0])/batch_size_m_predict)
    
    plt.title(r"Val MSE $Task(i_0=4, p_h=1, s=55, city=Madrid)$")
    plt.colorbar()
    plt.show()
    
    val_error = ((mean_plot_across_io_length[:, :, 0])).flatten()
    

    filenames = glob.glob(os.path.join(os.getcwd(), 
                                       "Spatial_results_multiple_runs", prefix, "_PM_spatial_complexity*.npy"))
    a = 0
    for npy in filenames:
        a = a + np.load(npy)
    # max_ = np.max(a)

    plt.imshow(a/cx_count)
    sprint (np.mean(a/cx_count))

    
    plt.title(r"$IC_{Pixel}~Task(i_0=4, p_h=1, s=55, city=Madrid)$")
    plt.colorbar()
    
    plt.show()    
    
    ic_train_data = a.flatten()
    
    sprint (scipy.stats.pearsonr(ic_train_data, val_error))
    sprint (scipy.stats.spearmanr(ic_train_data, val_error)) 
    sprint (scipy.stats.kendalltau(ic_train_data, val_error))
# Out:
# len(filenames) : 525
# mean_plot_across_io_length.shape : (55, 55, 1)
# np.mean(mean_plot_across_io_length)/batch_size_m_predict : 123.10397231765214
# np.mean(a/cx_count) : 1126.4655310216606
# scipy.stats.pearsonr(ic_train_data, val_error) : PearsonRResult(statistic=0.8284791065663524, pvalue=0.0)
# scipy.stats.spearmanr(ic_train_data, val_error) : SignificanceResult(statistic=0.8025656653097082, pvalue=0.0)
# scipy.stats.kendalltau(ic_train_data, val_error) : SignificanceResult(statistic=0.701587623925318, pvalue=0.0)

# %%
# Out:
# (4, 55, 55, 1)

# %%
import numpy as np
import os
import sys
import glob
from smartprint import smartprint as sprint

sys.path.append('../')

import config
import matplotlib.pyplot as plt
import scipy.stats

# for city in ["london", "madrid", "melbourne"]:
#     fileprefix_list = [city + "-4-1-85-"]

#     for prefix in fileprefix_list:
#         filenames = glob.glob(os.path.join(os.getcwd(), 
#                                            "Spatial_results_validation_errors/scale_85_compressed_spatial_dist/", prefix + "-spatial-errors", "*.npy"))
#         a = 0
#         for npy in filenames:
#             a = a + np.load(npy)
#         a = a/len(filenames)
#         max_ = np.max(a)

#         mean_plot_across_io_length = np.mean(a, axis=0)
#         sprint (mean_plot_across_io_length.shape)

#         plt.imshow((mean_plot_across_io_length[:, :, 0]) ** 0.5)

#         plt.title(prefix + "Val MAE error")
#         plt.colorbar()
#         plt.show()

#         val_error = ((mean_plot_across_io_length[:, :, 0]) ** 0.5).flatten()


#         filenames = glob.glob(os.path.join(os.getcwd(), 
#                                            "Spatial_results_validation_errors",city + "_PM_Spatial_val.npy"))
#         a = 0
#         for npy in filenames:
#             a = a + np.load(npy)
#         max_ = np.max(a)

#         plt.imshow(a/max_)

#         plt.title(prefix + " IC")
#         plt.colorbar()

#         plt.show()    

#         ic_train_data = a.flatten()

#         sprint (scipy.stats.pearsonr(ic_train_data, val_error))
#         sprint (scipy.stats.spearmanr(ic_train_data, val_error)) 
#         sprint (scipy.stats.kendalltau(ic_train_data, val_error))
        
for city in ["london", "madrid", "melbourne"]:
    fileprefix_list = [city + "-4-1-85-"]

    for prefix in fileprefix_list:
        filenames = glob.glob(os.path.join(os.getcwd(), 
                                           "Spatial_results_validation_errors/scale_85_compressed_spatial_dist/", prefix + "-spatial-errors", "*.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        a = a/len(filenames)
        max_ = np.max(a)

        mean_plot_across_io_length = np.mean(a, axis=0)
        sprint (mean_plot_across_io_length.shape)

        plt.imshow((mean_plot_across_io_length[:, :, 0]))

        plt.title(r"Val MSE $Task(i_0=4, p_h=1, s=85,city=$"+city.title())
        plt.colorbar()
        plt.show()

        val_error = ((mean_plot_across_io_length[:, :, 0])).flatten()


        filenames = glob.glob(os.path.join(os.getcwd(), 
                                           "Spatial_results_validation_errors",city + "_PM_Spatial_val.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        max_ = np.max(a)

        plt.imshow(a/max_)

        plt.title(r"$IC_{Pixel}~Task(i_0=4, p_h=1, s=85,city=$"+city.title())
        plt.colorbar()

        plt.show()    

        ic_train_data = a.flatten()

        sprint (scipy.stats.pearsonr(ic_train_data, val_error))
        sprint (scipy.stats.spearmanr(ic_train_data, val_error)) 
        sprint (scipy.stats.kendalltau(ic_train_data, val_error))
# Out:
# mean_plot_across_io_length.shape : (85, 85, 1)
# scipy.stats.pearsonr(ic_train_data, val_error) : PearsonRResult(statistic=0.6530259405433764, pvalue=0.0)
# scipy.stats.spearmanr(ic_train_data, val_error) : SignificanceResult(statistic=0.7212836189001659, pvalue=0.0)
# scipy.stats.kendalltau(ic_train_data, val_error) : SignificanceResult(statistic=0.6369264090553504, pvalue=0.0)
# mean_plot_across_io_length.shape : (85, 85, 1)
# scipy.stats.pearsonr(ic_train_data, val_error) : PearsonRResult(statistic=0.7746611967156665, pvalue=0.0)
# scipy.stats.spearmanr(ic_train_data, val_error) : SignificanceResult(statistic=0.7317977820716793, pvalue=0.0)
# scipy.stats.kendalltau(ic_train_data, val_error) : SignificanceResult(statistic=0.6274831325580482, pvalue=0.0)
# mean_plot_across_io_length.shape : (85, 85, 1)
# scipy.stats.pearsonr(ic_train_data, val_error) : PearsonRResult(statistic=0.8499963973645323, pvalue=0.0)
# ...

# %%
# Out:
# []

# %%
import glob
import os
import numpy as np
import scipy.stats
from tabulate import tabulate


cities = ["london", "madrid", "melbourne"]

# Initialize the table data
table_data = []

# Iterate over cities
for city in cities:
    fileprefix_list = [city + "-4-1-85-"]

    for prefix in fileprefix_list:
        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors/scale_85_compressed_spatial_dist/", prefix + "-spatial-errors", "*.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        a = a / len(filenames)
        max_ = np.max(a)

        mean_plot_across_io_length = np.mean(a, axis=0)


        val_error = ((mean_plot_across_io_length[:, :, 0]) ** 0.5).flatten()

        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors", city + "_PM_Spatial_val.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        max_ = np.max(a)
        
        plt.imshow(a/max_)

        plt.title(prefix + " IC")
        plt.colorbar()
        plt.show()
        
        ic_train_data = a.flatten()

        correlation_coefficient, _ = scipy.stats.pearsonr(ic_train_data, val_error)

        # Add row to the table data
        table_data.append(["val_mae", city, "Pearson's Correlation", correlation_coefficient])

        
        
# Iterate over cities
for city in cities:
    fileprefix_list = [city + "-4-1-85-"]

    for prefix in fileprefix_list:
        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors/scale_85_compressed_spatial_dist/", prefix + "-spatial-errors", "*.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        a = a / len(filenames)
        max_ = np.max(a)

        mean_plot_across_io_length = np.mean(a, axis=0)
        val_error = ((mean_plot_across_io_length[:, :, 0]) ).flatten()

        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors", city + "_PM_Spatial_val.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        max_ = np.max(a)
        ic_train_data = a.flatten()

        correlation_coefficient, _ = scipy.stats.pearsonr(ic_train_data, val_error)

        # Add row to the table data
        table_data.append(["val_mse", city, "Pearson's Correlation", correlation_coefficient])
        
# Generate LaTeX table
table_headers = ["Error Type", "City", "Correlation Type", "Correlation"]
table = tabulate(table_data, headers=table_headers, tablefmt="latex")

# Print the table
print(table)
# Out:
# \begin{tabular}{lllr}
# \hline
#  Error Type   & City      & Correlation Type      &   Correlation \\
# \hline
#  val\_mae      & london    & Pearson's Correlation &      0.923601 \\
#  val\_mae      & madrid    & Pearson's Correlation &      0.895055 \\
#  val\_mae      & melbourne & Pearson's Correlation &      0.962903 \\
#  val\_mse      & london    & Pearson's Correlation &      0.653026 \\
#  val\_mse      & madrid    & Pearson's Correlation &      0.774661 \\
#  val\_mse      & melbourne & Pearson's Correlation &      0.849996 \\
# \hline
# \end{tabular}

# %%
import glob
import os
import numpy as np
import scipy.stats
from tabulate import tabulate


import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}

cities = ["london", "madrid", "melbourne"]

# Initialize the table data
table_data = []


# cities = ["madrid"]
# Iterate over cities
for city in cities:
    fileprefix_list = [city + "-4-1-85-"]

    # Get mask
    for prefix in fileprefix_list:
        rawfilenames = glob.glob(os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy"))
        sprint (os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy"))
        sprint (len(rawfilenames))
        a = 0
        for npy in rawfilenames[:100]:
            a = a + np.load(npy)
        sprint ("Before", a.shape)            
        a = np.mean(a, axis=-1)
        sprint ("After", a.shape)            
        # plt.hist(a[a>0].flatten(), 300)
        # plt.show()
        non_zero_mask = (a > 100)
        
    
    for prefix in fileprefix_list:
        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors/re_run_spatial_validation_errors", prefix + "-spatial-errors", "*.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        a = a / len(filenames)
        max_ = np.max(a)

        mean_plot_across_io_length = np.mean(a, axis=0)
        
#         plt.imshow((mean_plot_across_io_length[:, :, 0]) ** 0.5)

#         plt.title(prefix + "Val MAE error")
#         plt.colorbar()
#         plt.tight_layout()
#         plt.savefig("VAL_MAE_spatial_dist_val_data"+city+".png")        
#         plt.show()
        
        val_error = ((mean_plot_across_io_length[:, :, 0])[non_zero_mask]).flatten() ** 0.5

        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors", city + "_PM_Spatial_val.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        max_ = np.max(a)
        
        
        ic_train_data = ic_train_data/ np.max(ic_train_data)
        val_error = val_error / np.max(val_error)

        x = ic_train_data
        y = val_error

        # Sort the x values and compute their CDF
        x_sorted = np.sort(x)
        x_cdf = np.linspace(0, 1, len(x_sorted))

        # Sort the y values and compute their CDF
        y_sorted = np.sort(y)
        y_cdf = np.linspace(0, 1, len(y_sorted))

        # Plot the CDFs
        plt.plot(x_sorted, x_cdf, '--',label='IC (train) '+city, color=city_color[city])
        plt.plot(y_sorted, y_cdf, label='Val MAE '+city, color=city_color[city])

        
        # plt.imshow(a/max_)

        # plt.title(prefix + " IC")
        # plt.colorbar()
        # plt.tight_layout()
        # plt.savefig("IC_spatial_dist_train_data"+city+".png")
        # plt.show()
        
        sprint ((a>0).sum())
        ic_train_data = a[non_zero_mask].flatten()
        sprint ((ic_train_data>0).sum())
        
        correlation_coefficient, p_value = scipy.stats.pearsonr(ic_train_data, val_error)

        # Add row to the table data
        table_data.append(["val_mae", city, correlation_coefficient, p_value])


# # Iterate over cities
# for city in cities:
#     fileprefix_list = [city + "-4-1-85-"]

#     for prefix in fileprefix_list:
#         filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors/re_run_spatial_validation_errors/", prefix + "-spatial-errors", "*.npy"))
#         a = 0
#         for npy in filenames:
#             a = a + np.load(npy)
#         a = a / len(filenames)
#         max_ = np.max(a)

#         mean_plot_across_io_length = np.mean(a, axis=0)
        
#         val_error = (mean_plot_across_io_length[:, :, 0][non_zero_mask]).flatten()

#         filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors", city + "_PM_Spatial_val.npy"))
#         a = 0
#         for npy in filenames:
#             a = a + np.load(npy)
#         max_ = np.max(a)
#         ic_train_data = a[non_zero_mask].flatten()

#         correlation_coefficient, p_value = scipy.stats.pearsonr(ic_train_data, val_error)

#         # Add row to the table data
#         table_data.append(["val_mse", city, correlation_coefficient, p_value])

# Generate LaTeX table
table_headers = ["Error Type", "City", "Pearson's Correlation", "p-value"]
table = tabulate(table_data, headers=table_headers, tablefmt="latex")

# Add table caption and label
table = "\\begin{table}[h]\n" \
        "\\centering\n" \
        "\\caption{Correlation between each spatial bin of IC and validation errors}\n" \
        "\\label{tab:spatial_ic}\n" \
        f"{table}\n" \
        "\\end{table}"

print(table)


plt.xlabel('Values')
plt.ylabel('Cumulative Probability')
# plt.title('CDF Plot of X and Y')
plt.legend()
# plt.grid(True)
plt.show()
# Out:
# os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy") : /Users/nishant/Downloads/NeurIPS2022-traffic4cast/train_data_all_cities/london-4-1-85-/*.npy
# len(rawfilenames) : 18060
# "Before", a.shape : Before (85, 85, 4)
# "After", a.shape : After (85, 85)
# (a>0).sum() : 1555
# (ic_train_data>0).sum() : 1423
# os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy") : /Users/nishant/Downloads/NeurIPS2022-traffic4cast/train_data_all_cities/madrid-4-1-85-/*.npy
# len(rawfilenames) : 18060
# "Before", a.shape : Before (85, 85, 4)
# "After", a.shape : After (85, 85)
# (a>0).sum() : 1877
# (ic_train_data>0).sum() : 1408
# os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy") : /Users/nishant/Downloads/NeurIPS2022-traffic4cast/train_data_all_cities/melbourne-4-1-85-/*.npy
# len(rawfilenames) : 18060
# "Before", a.shape : Before (85, 85, 4)
# "After", a.shape : After (85, 85)
# (a>0).sum() : 1524
# (ic_train_data>0).sum() : 1317
# \begin{table}[h]
# \centering
# ...

# %%
import glob
import os
import numpy as np
import scipy.stats
from tabulate import tabulate


import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}

cities = ["london", "madrid", "melbourne"]

# Initialize the table data
table_data = []


# cities = ["madrid"]
# Iterate over cities
cx_count = 500 # number of points used to compute Cx
batch_size_m_predict = 16 
for city in cities:
    fileprefix_list = [city + "-4-1-85-"]

    # Get mask
    for prefix in fileprefix_list:
        rawfilenames = glob.glob(os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy"))
        sprint (os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy"))
        sprint (len(rawfilenames))
        a = 0
        for npy in rawfilenames[:100]:
            a = a + np.load(npy)
        sprint ("Before", a.shape)            
        a = np.mean(a, axis=-1)
        sprint ("After", a.shape)            
        # plt.hist(a[a>0].flatten(), 300)
        # plt.show()
        non_zero_mask = (a > 100)
        
    
    for prefix in fileprefix_list:
        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors/re_run_spatial_validation_errors", prefix + "-spatial-errors", "*.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        a = a / len(filenames)
        max_ = np.max(a)

        mean_plot_across_io_length = np.mean(a, axis=0)
        max_ = np.max(mean_plot_across_io_length.flatten())

        
        # plt.imshow((mean_plot_across_io_length[:, :, 0])/ max_)

        
        plt.imshow((mean_plot_across_io_length[:, :, 0])/batch_size_m_predict)

        plt.title(r"Val MSE $Task(i_0=4, p_h=1, s=85,city=$"+city.title()+")")
        
        plt.colorbar()
        plt.tight_layout()
        plt.savefig("VAL_MSE_spatial_dist_val_data"+city+".png")        
        plt.show()
        
        val_error = ((mean_plot_across_io_length[:, :, 0])[non_zero_mask]).flatten() 

        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors", city + "_PM_Spatial_val.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        max_ = np.max(a)
        
        
        ic_train_data = ic_train_data/ np.max(ic_train_data)
        val_error = val_error / np.max(val_error)

        x = ic_train_data
        y = val_error

        # Sort the x values and compute their CDF
        x_sorted = np.sort(x)
        x_cdf = np.linspace(0, 1, len(x_sorted))

        # Sort the y values and compute their CDF
        y_sorted = np.sort(y)
        y_cdf = np.linspace(0, 1, len(y_sorted))

        # # Plot the CDFs
        # plt.plot(x_sorted, x_cdf, '--',label='IC (train) '+city, color=city_color[city])
        # plt.plot(y_sorted, y_cdf, label='Val MAE '+city, color=city_color[city])

        
        plt.imshow(a/cx_count)

        plt.title(r"$IC_{Pixel}~Task(i_0=4, p_h=1, s=85,city=$"+city.title()+")")
        plt.colorbar()
        plt.tight_layout()
        plt.savefig("IC_spatial_dist_train_data"+city+".png")
        plt.show()
        
        sprint ((a>0).sum())
        ic_train_data = a[non_zero_mask].flatten()
        sprint ((ic_train_data>0).sum())
        
        correlation_coefficient, p_value = scipy.stats.pearsonr(ic_train_data, val_error)

        # Add row to the table data
        table_data.append(["val_mse_non_zero", city.title(), correlation_coefficient, p_value])


# Iterate over cities
for city in cities:
    fileprefix_list = [city + "-4-1-85-"]

    for prefix in fileprefix_list:
        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors/re_run_spatial_validation_errors/", prefix + "-spatial-errors", "*.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        a = a / len(filenames)
        max_ = np.max(a)

        mean_plot_across_io_length = np.mean(a, axis=0)
        
        val_error = (mean_plot_across_io_length[:, :, 0]).flatten()

        filenames = glob.glob(os.path.join(os.getcwd(), "Spatial_results_validation_errors", city + "_PM_Spatial_val.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        max_ = np.max(a)
        ic_train_data = a.flatten()

        correlation_coefficient, p_value = scipy.stats.pearsonr(ic_train_data, val_error)

        # Add row to the table data
        table_data.append(["val_mse", city.title(), correlation_coefficient, p_value])

# Generate LaTeX table
table_headers = ["Error Type", "City", "Pearson's Correlation", "p-value"]
table = tabulate(table_data, headers=table_headers, tablefmt="latex")

# Add table caption and label
table = "\\begin{table}[h]\n" \
        "\\centering\n" \
        "\\caption{Correlation between each spatial bin of IC and validation errors}\n" \
        "\\label{tab:spatial_ic}\n" \
        f"{table}\n" \
        "\\end{table}"

print(table)


# plt.xlabel('Values')
# plt.ylabel('Cumulative Probability')
# # plt.title('CDF Plot of X and Y')
plt.legend()
# plt.grid(True)
plt.show()
# Out:
# os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy") : /Users/nishant/Downloads/NeurIPS2022-traffic4cast/train_data_all_cities/london-4-1-85-/*.npy
# len(rawfilenames) : 18060
# "Before", a.shape : Before (85, 85, 4)
# "After", a.shape : After (85, 85)
# (a>0).sum() : 1555
# (ic_train_data>0).sum() : 1423
# os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy") : /Users/nishant/Downloads/NeurIPS2022-traffic4cast/train_data_all_cities/madrid-4-1-85-/*.npy
# len(rawfilenames) : 18060
# "Before", a.shape : Before (85, 85, 4)
# "After", a.shape : After (85, 85)
# (a>0).sum() : 1877
# (ic_train_data>0).sum() : 1408
# os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy") : /Users/nishant/Downloads/NeurIPS2022-traffic4cast/train_data_all_cities/melbourne-4-1-85-/*.npy
# len(rawfilenames) : 18060
# "Before", a.shape : Before (85, 85, 4)
# "After", a.shape : After (85, 85)
# (a>0).sum() : 1524
# (ic_train_data>0).sum() : 1317
# ...

# %%
import glob
import os
import numpy as np
import scipy.stats
from tabulate import tabulate


import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}

# cities = ["london", "madrid", "melbourne"]

# Initialize the table data
table_data = []


cities = ["madrid"]
# Iterate over cities
fileprefix_list = ["madrid-4-1-55-"]

cx_count = 3000 # number of points used to compute Cx
batch_size_m_predict = 55 

for city in cities:

    # Get mask
    for prefix in fileprefix_list:
        rawfilenames = glob.glob(os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy"))
        sprint (os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy"))
        sprint (len(rawfilenames))
        a = 0
        for npy in rawfilenames[:100]:
            a = a + np.load(npy)
        sprint ("Before", a.shape)            
        a = np.mean(a, axis=-1)
        sprint ("After", a.shape)            
        # plt.hist(a[a>0].flatten(), 300)
        # plt.show()
        non_zero_mask = (a > 100)
        
    
    for prefix in fileprefix_list:
        filenames = glob.glob(os.path.join(os.getcwd(), 
                                       "Spatial_results_validation_errors/", prefix + "-spatial-errors", "*.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        a = a / len(filenames)
        max_ = np.max(a)

        mean_plot_across_io_length = np.mean(a, axis=0)
        max_ = np.max(mean_plot_across_io_length.flatten())

        
        # plt.imshow((mean_plot_across_io_length[:, :, 0])/ max_)

        
        plt.imshow((mean_plot_across_io_length[:, :, 0])/batch_size_m_predict)

        plt.title(r"Val MSE $Task(i_0=4, p_h=1, s=55,city=$"+city.title()+")")
        
        plt.colorbar()
        plt.tight_layout()
        plt.savefig("VAL_MSE_spatial_dist_val_data"+city+".png")        
        plt.show()
        
        val_error = ((mean_plot_across_io_length[:, :, 0])[non_zero_mask]).flatten() 

        filenames = glob.glob(os.path.join(os.getcwd(), 
                                       "Spatial_results_multiple_runs", prefix, "_PM_spatial_complexity*.npy"))        
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        max_ = np.max(a)
        
        
        ic_train_data = ic_train_data/ np.max(ic_train_data)
        val_error = val_error / np.max(val_error)

        x = ic_train_data
        y = val_error

        # Sort the x values and compute their CDF
        x_sorted = np.sort(x)
        x_cdf = np.linspace(0, 1, len(x_sorted))

        # Sort the y values and compute their CDF
        y_sorted = np.sort(y)
        y_cdf = np.linspace(0, 1, len(y_sorted))

        # # Plot the CDFs
        # plt.plot(x_sorted, x_cdf, '--',label='IC (train) '+city, color=city_color[city])
        # plt.plot(y_sorted, y_cdf, label='Val MAE '+city, color=city_color[city])

        
        plt.imshow(a/cx_count)

        plt.title(r"$IC_{Pixel}~Task(i_0=4, p_h=1, s=55,city=$"+city.title()+")")
        plt.colorbar()
        plt.tight_layout()
        plt.savefig("IC_spatial_dist_train_data"+city+".png")
        plt.show()
        
        sprint ((a>0).sum())
        ic_train_data = a[non_zero_mask].flatten()
        sprint ((ic_train_data>0).sum())
        
        correlation_coefficient, p_value = scipy.stats.pearsonr(ic_train_data, val_error)

        # Add row to the table data
        table_data.append(["val_mse_non_zero", city.title(), correlation_coefficient, p_value])


# Iterate over cities
for city in cities:
    fileprefix_list = [city + "-4-1-55-"]

    for prefix in fileprefix_list:
        filenames = glob.glob(os.path.join(os.getcwd(), 
                                       "Spatial_results_validation_errors/", prefix + "-spatial-errors", "*.npy"))
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        a = a / len(filenames)
        max_ = np.max(a)

        mean_plot_across_io_length = np.mean(a, axis=0)
        
        val_error = (mean_plot_across_io_length[:, :, 0]).flatten()

        filenames = glob.glob(os.path.join(os.getcwd(), 
                                       "Spatial_results_multiple_runs", prefix, "_PM_spatial_complexity*.npy"))      
        a = 0
        for npy in filenames:
            a = a + np.load(npy)
        max_ = np.max(a)
        ic_train_data = a.flatten()

        correlation_coefficient, p_value = scipy.stats.pearsonr(ic_train_data, val_error)

        # Add row to the table data
        table_data.append(["val_mse", city.title(), correlation_coefficient, p_value])

# Generate LaTeX table
table_headers = ["Error Type", "City", "Pearson's Correlation", "p-value"]
table = tabulate(table_data, headers=table_headers, tablefmt="latex")

# Add table caption and label
table = "\\begin{table}[h]\n" \
        "\\centering\n" \
        "\\caption{Correlation between each spatial bin of IC and validation errors}\n" \
        "\\label{tab:spatial_ic}\n" \
        f"{table}\n" \
        "\\end{table}"

print(table)


# plt.xlabel('Values')
# plt.ylabel('Cumulative Probability')
# # plt.title('CDF Plot of X and Y')
plt.legend()
# plt.grid(True)
plt.show()
# Out:
# os.path.join(config.TRAINING_DATA_FOLDER, prefix, "*.npy") : /Users/nishant/Downloads/NeurIPS2022-traffic4cast/train_data_all_cities/madrid-4-1-55-/*.npy
# len(rawfilenames) : 10879
# "Before", a.shape : Before (55, 55, 4)
# "After", a.shape : After (55, 55)
# (a>0).sum() : 1024
# (ic_train_data>0).sum() : 778
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# \begin{table}[h]
# \centering
# \caption{Correlation between each spatial bin of IC and validation errors}
# \label{tab:spatial_ic}
# \begin{tabular}{llrr}
# \hline
#  Error Type       & City   &   Pearson's Correlation &      p-value \\
# \hline
#  val\_mse\_non\_zero & Madrid &                0.842787 & 5.92115e-211 \\
#  val\_mse          & Madrid &                0.828479 & 0            \\
# \hline
# \end{tabular}
# \end{table}

# %%
a.shape
# Out:
# (85, 85)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}

ic_train_data = ic_train_data/ np.max(ic_train_data)
val_error = val_error / np.max(val_error)

x = ic_train_data
y = val_error

# Sort the x values and compute their CDF
x_sorted = np.sort(x)
x_cdf = np.linspace(0, 1, len(x_sorted))

# Sort the y values and compute their CDF
y_sorted = np.sort(y)
y_cdf = np.linspace(0, 1, len(y_sorted))

# Plot the CDFs
plt.plot(x_sorted, x_cdf, label='IC', color=city_color[city])
plt.plot(y_sorted, y_cdf, label='Val_mae')

plt.xlabel('Values')
plt.ylabel('Cumulative Probability')
plt.title('CDF Plot of X and Y')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Out:
# ...
# london_85_days processed:   0%|                                                                                                                                                                                                                                                                                                                         | 0/235 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 4
#       2 from preprocessing.ProcessRaw import ProcessRaw
#       3 for city in cities[0:1]:
# ----> 4     ProcessRaw(cityname=city, i_o_length=4, prediction_horizon=1, grid_size=85)
#
# File ~/Documents/GitHub/CTP/exploration/CATP/plotting/../preprocessing/ProcessRaw.py:51, in ProcessRaw.__init__(self, cityname, i_o_length, prediction_horizon, grid_size)
#      48 self.create_spatial_npy_from_loop_lat_lon()
#      50 self.date_list = None
# ...
