# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("../../")
import config
import numpy as np

plt.figure(figsize=(10, 4))  # Width, height in inches

data_for_df_x = pd.read_csv("big_model_val_error_evolution_x.csv", header=None)
data_for_df_y = pd.read_csv("big_model_val_error_evolution_y.csv", header=None)

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}
print (data_for_df_x.head())
for city in config.city_list:
    cityname = city.lower()    
    plt.plot(data_for_df_x[data_for_df_x[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
             data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
        label=cityname + " f DEP-4-FIL-128" + "; MC=" + str(dict_MC["big",cityname]) ,
             color=city_color[cityname]
    )
    print (" Big model mean:" , np.nanmean(data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist()))
data_for_df_x = pd.read_csv("small_model_val_error_evolution_x.csv", header=None)
data_for_df_y = pd.read_csv("small_model_val_error_evolution_y.csv", header=None)

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}
print (data_for_df_x.head())
for city in config.city_list:
    cityname = city.lower()    
    plt.plot(
            data_for_df_x[data_for_df_x[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
             data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
        label=cityname + " f DEP-2-FIL-64" + "; MC=" + str(dict_MC["small",cityname]) ,
                alpha=0.4,
             color=city_color[cityname]
        
    )
    print (" Small model mean:" , np.nanmean(data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist()))
plt.legend(ncol=2)
# plt.gca().set_aspect(14000)
# plt.ylim(1000, 10800)
# plt.yscale("log")
plt.ylabel("Validation sq. error for each sample", fontsize=11)
plt.xlabel("Validation data time stamp", fontsize=11)
plt.tight_layout()
plt.savefig("ModelErrors-overtime_cities.png", dpi=300)
plt.show()
# Out:
#         0          1          2          3          4          5     \
# 0     london  48.947917  49.968750  50.989583  52.010417  53.031250
# 1  melbourne  48.500000  49.500000  50.500000  51.500000  52.500000
# 2     madrid  49.281250  50.291667  51.302083  52.312500  53.322917
#
#         6          7          8          9     ...         9263         9264  \
# 0  54.052083  55.072917  56.093750  57.114583  ...  9401.614583  9402.666667
# 1  53.500000  54.500000  55.500000  56.500000  ...          NaN          NaN
# 2  54.333333  55.343750  56.354167  57.364583  ...          NaN          NaN
#
#          9265         9266         9267        9268         9269         9270  \
# 0  9403.71875  9404.760417  9405.802083  9406.84375  9407.885417  9408.927083
# 1         NaN          NaN          NaN         NaN          NaN          NaN
# 2         NaN          NaN          NaN         NaN          NaN          NaN
#
#          9271         9272
# 0  9409.96875  9411.010417
# ...

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("../../")
import config
import numpy as np

plt.figure(figsize=(10, 4))  # Width, height in inches

data_for_df_x = pd.read_csv("big_model_val_error_evolution_x.csv", header=None)
data_for_df_y = pd.read_csv("big_model_val_error_evolution_y.csv", header=None)

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}
print (data_for_df_x.head())
for city in config.city_list:
    cityname = city.lower()    
    plt.plot(data_for_df_x[data_for_df_x[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
             data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
        label=cityname + " f DEP-4-FIL-128" + "; MC=" + str(dict_MC["big",cityname]) ,
             color=city_color[cityname]
    )
    print (" Big model mean:" , np.nanmean(data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist()))
data_for_df_x = pd.read_csv("small_model_val_error_evolution_x.csv", header=None)
data_for_df_y = pd.read_csv("small_model_val_error_evolution_y.csv", header=None)

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}
print (data_for_df_x.head())
for city in config.city_list:
    cityname = city.lower()    
    plt.plot(
            data_for_df_x[data_for_df_x[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
             np.array(data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist())/ np.max(), 
        label=cityname + " f DEP-2-FIL-64" + "; MC=" + str(dict_MC["small",cityname]) ,
                alpha=0.4,
             color=city_color[cityname]
        
    )
    print (" Small model mean:" , np.nanmean(data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist()))
plt.legend(ncol=2)
# plt.gca().set_aspect(14000)
# plt.ylim(1000, 10800)
# plt.yscale("log")
plt.ylabel("Validation sq. error for each sample", fontsize=11)
plt.xlabel("Validation data time stamp", fontsize=11)
plt.tight_layout()
plt.savefig("ModelErrors-overtime_cities.png", dpi=300)
plt.show()

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("../../")
import config
import numpy as np

plt.figure(figsize=(10, 4))  # Width, height in inches

data_for_df_x = pd.read_csv("big_model_val_error_evolution_x.csv", header=None)
data_for_df_y = pd.read_csv("big_model_val_error_evolution_y.csv", header=None)

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}
print (data_for_df_x.head())
for city in ["madrid"]:
    cityname = city.lower()    
    plt.plot(data_for_df_x[data_for_df_x[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
             data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
        label=cityname + " f DEP-4-FIL-128" + "; MC=" + str(dict_MC["big","madrid"]) ,
             color=city_color[cityname]
    )
    print (" Big model mean:" , np.nanmean(data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist()))
data_for_df_x = pd.read_csv("small_model_val_error_evolution_x.csv", header=None)
data_for_df_y = pd.read_csv("small_model_val_error_evolution_y.csv", header=None)

city_color = {"london" : "#E69F00", 
             "melbourne": "#0072B2",
             "madrid": "#CC79A7"}
print (data_for_df_x.head())
for city in ["madrid"]:#  config.city_list:
    cityname = city.lower()    
    plt.plot(
            data_for_df_x[data_for_df_x[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
             data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist(), 
        label=cityname + " f DEP-2-FIL-64" + "; MC=" + str(dict_MC["small","madrid"]) ,
                alpha=0.4,
             color=city_color[cityname]
        
    )
    print (" Small model mean:" , np.nanmean(data_for_df_y[data_for_df_y[0] == cityname].T[1:].to_numpy().flatten().tolist()))
plt.legend(ncol=1)
# plt.gca().set_aspect(14000)
plt.ylim(1000, 10800)
# plt.yscale("log")
plt.ylabel("MSE", fontsize=11)
plt.xlabel("Validation data time stamp", fontsize=11)
plt.tight_layout()
plt.savefig("ModelErrors-overtime_madrid.png", dpi=300)
plt.show()
# Out:
#         0          1          2          3          4          5     \
# 0     london  48.947917  49.968750  50.989583  52.010417  53.031250
# 1  melbourne  48.500000  49.500000  50.500000  51.500000  52.500000
# 2     madrid  49.281250  50.291667  51.302083  52.312500  53.322917
#
#         6          7          8          9     ...         9263         9264  \
# 0  54.052083  55.072917  56.093750  57.114583  ...  9401.614583  9402.666667
# 1  53.500000  54.500000  55.500000  56.500000  ...          NaN          NaN
# 2  54.333333  55.343750  56.354167  57.364583  ...          NaN          NaN
#
#          9265         9266         9267        9268         9269         9270  \
# 0  9403.71875  9404.760417  9405.802083  9406.84375  9407.885417  9408.927083
# 1         NaN          NaN          NaN         NaN          NaN          NaN
# 2         NaN          NaN          NaN         NaN          NaN          NaN
#
#          9271         9272
# 0  9409.96875  9411.010417
# ...

# %%
# Out:
# smallmodellondon MC : 1200.9580323538255
# smallmodelmadrid MC : 4285.701799682609
# smallmodelmelbourne MC : 1373.8332946495625
# bigmodellondon MC : 1360.627080852645
# bigmodelmadrid MC : 5993.558285334216
# bigmodelmelbourne MC : 1692.8290764865494

# %%
import os

# List of file paths, you can use glob or os.listdir() to automate this
file_paths = [
    'validation-default_model--adam-0p001-temporal-experiment-val-error-small-modellondon-4-1-55-.csv',
    'validation-default_model--adam-0p001-temporal-experiment-val-error-small-modelmadrid-4-1-55-.csv',
    'validation-default_model--adam-0p001-temporal-experiment-val-error-small-modelmelbourne-4-1-55-.csv',
    'validation-default_model--adam-0p001-temporal-experiment-val-error-big-modellondon-4-1-55-.csv',
    'validation-default_model--adam-0p001-temporal-experiment-val-error-big-modelmadrid-4-1-55-.csv',
    'validation-default_model--adam-0p001-temporal-experiment-val-error-big-modelmelbourne-4-1-55-.csv'
]

for file_path in file_paths:
    # Extract the short filename (e.g., 'small-modellondon')
    short_filename = os.path.basename(file_path).split('-')[-6] +  os.path.basename(file_path).split('-')[-5] 
    # Read the last line of the file
    with open(file_path, 'r') as file:
        last_line = file.readlines()[-1].strip()
    # Print the short filename and the last line
    print(short_filename + " MC : " + last_line.split(",")[5])



dict_MC = {}
dict_MC = {
    ("small", "london"): 1200.96,
    ("small", "madrid"): 4285.70,
    ("small", "melbourne"): 1373.83,
    ("big", "london"): 1360.63,
    ("big", "madrid"): 5993.56,
    ("big", "melbourne"): 1692.83
}
# Out:
# smallmodellondon MC : 1200.9580323538255
# smallmodelmadrid MC : 4285.701799682609
# smallmodelmelbourne MC : 1373.8332946495625
# bigmodellondon MC : 1360.627080852645
# bigmodelmadrid MC : 5993.558285334216
# bigmodelmelbourne MC : 1692.8290764865494
