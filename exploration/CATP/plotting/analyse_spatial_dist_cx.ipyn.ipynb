# %%
import numpy as np
import os
import sys

sys.path.append('../')

import config
import matplotlib.pyplot as plt

fileprefix_list = ["london-4-1-55-" , "london-4-1-105-", "madrid-4-1-55-", "melbourne-4-1-55-", \
                  "london-4-1-25-" , "london-4-1-25-", "madrid-4-1-25-", "melbourne-4-1-25-"]

for prefix in fileprefix_list:
    path_ = os.path.join(os.getcwd(), "Spatial_results", prefix, "_PM_spatial_complexity.npy")
    assert os.path.exists(path_)
    a = np.load(path_)
    
    plt.imshow(np.log(a))
    plt.title(prefix)
    plt.colorbar()
    plt.show()
# Out:
# /var/folders/dp/q2rz500s2kj79pnbkf36h7ch0000gq/T/ipykernel_49882/4189270243.py:18: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(a))

# %%
path_
# Out:
# '/Users/nishant/Documents/GitHub/CTP/exploration/CATP/plotting/Spatial_results/london-4-1-105/_PM_spatial_complexity.npy'

# %%
a
# Out:
# array([[0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#         0.00000000e+000, 4.16313000e+005, 3.08259200e+002,
#         2.10456667e+004, 0.00000000e+000, 5.59138519e+004,
#         1.36082709e-001, 5.98221344e+000, 0.00000000e+000,
#         2.08634000e+005, 1.45526350e-001, 0.00000000e+000,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#         0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#         0.00000000e+000, 0.00000000e+000, 3.19859000e+005,
#         1.00449288e+002, 9.17086296e+004, 1.44700977e+004,
#         6.67061328e+003, 2.95457554e+000, 2.85003455e+000,
#         6.30442601e+001, 4.57944880e+000, 3.99287040e+002,
# ...
